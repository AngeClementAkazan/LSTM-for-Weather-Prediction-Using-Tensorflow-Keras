# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeClementAkazan/LSTM-for-Weather-Prediction-Using-Tensorflow-Keras/blob/main/LSTM_Temperature_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LSTM  for Temperature Prediction

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation,TimeDistributed
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns
from google.colab import files
# mpl.rcParams['figure.figsize'] = (12,8)
mpl.rcParams['axes.grid'] = True

# %% [markdown]
# **Data Importation and Information**

# %%
df = pd.read_csv(r'/content/Daily Abidjan_data.csv')
print(df.info())
df.describe()
df.head(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2557 non-null   object
#  1   T2M     2557 non-null   float64
#  2   WS2M    2557 non-null   float64
#  3   QV2M    2557 non-null   float64
#  4   RH2M    2557 non-null   float64
#  5   PREC    2557 non-null   float64
#  6   PS      2557 non-null   float64
#  7   SWRD    2557 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 159.9+ KB
# None
#        Date    T2M  WS2M   QV2M   RH2M  PREC      PS  SWRD
# 0  01/01/15  26.56  1.40  10.74  52.75  0.01  100.63  5.15
# 1  02/01/15  26.72  1.86   9.34  44.62  0.00  100.58  5.58
# 2  03/01/15  26.72  1.80  14.59  69.06  0.01  100.70  5.73
# 3  04/01/15  27.51  1.45  16.30  73.00  0.25  100.74  5.39

# %% [markdown]
# **Variable ploting**

# %%
df.index = pd.to_datetime(df['Date'],infer_datetime_format=True )
plt.figure(figsize=(20,9))
df.set_index('Date')[['T2M', 'WS2M', 'QV2M', 'RH2M', 'PREC', 'PS',
       'SWRD']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0b1c4cd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0f72c210>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0af49e50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0af0e1d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0aec6510>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0ae7f850>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1d0ae37c10>],
#       dtype=object)

# %%
#################### Datapreprocessing For Temperature   #####################

# Scalling
df_input= df[['T2M', 'WS2M', 'QV2M', 'RH2M', 'PREC', 'PS','SWRD']].sort_index()
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(df_input)



# define X and Y
features=data_scaled
target=data_scaled[:,0]
# Time series data generation


 # Splitting the dataset into training set and test set
 
X_train,  y_train = features[:1636,:], target[:1636]
X_val,y_val= features[1636:2045,:], target[1636:2045]
X_test,y_test= features[2045:,:], target[2045:]

# Data Transformation 

window_length= 14
b_size= 124
features_num=7
train_generator= TimeseriesGenerator(X_train,y_train,length=window_length,sampling_rate=1,batch_size=b_size)
val_generator= TimeseriesGenerator(X_val,y_val,length=window_length,sampling_rate=1,batch_size=b_size)
test_generator= TimeseriesGenerator(X_test,y_test,length=window_length,sampling_rate=1,batch_size=b_size)

# %% [markdown]
# #  LSTM

# %%
########################################################################################################################
#####################################   LSTM MOdel for    Temperature prediction       #################################
########################################################################################################################



model=Sequential()
model.add(LSTM(94, activation='relu', input_shape=(window_length, features_num), return_sequences=False))
# model.add(LSTM(24, activation='relu', return_sequences=True))
# model.add(LSTM(12, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.summary()

# Early stopping: Model stops if the validation loss does not improve after 3 more iteration the algorithm stop
early_stopping= tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=50,mode='min')
model.compile(loss=tf.losses.MeanSquaredError(),optimizer='adam',metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.RootMeanSquaredError()])
history=model.fit(train_generator,epochs=160,shuffle=False, validation_data=val_generator,callbacks=[early_stopping])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 94)                38352
#
#  dropout_2 (Dropout)         (None, 94)                0
#
#  dense_2 (Dense)             (None, 1)                 95
#
# =================================================================
# Total params: 38,447
# Trainable params: 38,447
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/160
# 14/14 [==============================] - 2s 49ms/step - loss: 0.0934 - mean_absolute_error: 0.2446 - root_mean_squared_error: 0.3056 - val_loss: 0.0565 - val_mean_absolute_error: 0.2001 - val_root_mean_squared_error: 0.2377
# Epoch 2/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0406 - mean_absolute_error: 0.1675 - root_mean_squared_error: 0.2015 - val_loss: 0.0497 - val_mean_absolute_error: 0.1839 - val_root_mean_squared_error: 0.2229
# Epoch 3/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0341 - mean_absolute_error: 0.1520 - root_mean_squared_error: 0.1846 - val_loss: 0.0415 - val_mean_absolute_error: 0.1690 - val_root_mean_squared_error: 0.2036
# Epoch 4/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0312 - mean_absolute_error: 0.1446 - root_mean_squared_error: 0.1767 - val_loss: 0.0387 - val_mean_absolute_error: 0.1610 - val_root_mean_squared_error: 0.1968
# Epoch 5/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0283 - mean_absolute_error: 0.1363 - root_mean_squared_error: 0.1683 - val_loss: 0.0355 - val_mean_absolute_error: 0.1518 - val_root_mean_squared_error: 0.1883
# Epoch 6/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0259 - mean_absolute_error: 0.1302 - root_mean_squared_error: 0.1608 - val_loss: 0.0328 - val_mean_absolute_error: 0.1429 - val_root_mean_squared_error: 0.1812
# Epoch 7/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0244 - mean_absolute_error: 0.1245 - root_mean_squared_error: 0.1562 - val_loss: 0.0317 - val_mean_absolute_error: 0.1369 - val_root_mean_squared_error: 0.1779
# Epoch 8/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0228 - mean_absolute_error: 0.1200 - root_mean_squared_error: 0.1511 - val_loss: 0.0310 - val_mean_absolute_error: 0.1329 - val_root_mean_squared_error: 0.1761
# Epoch 9/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0234 - mean_absolute_error: 0.1193 - root_mean_squared_error: 0.1529 - val_loss: 0.0300 - val_mean_absolute_error: 0.1284 - val_root_mean_squared_error: 0.1732
# Epoch 10/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0233 - mean_absolute_error: 0.1180 - root_mean_squared_error: 0.1527 - val_loss: 0.0295 - val_mean_absolute_error: 0.1268 - val_root_mean_squared_error: 0.1717
# Epoch 11/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0209 - mean_absolute_error: 0.1131 - root_mean_squared_error: 0.1444 - val_loss: 0.0290 - val_mean_absolute_error: 0.1250 - val_root_mean_squared_error: 0.1701
# Epoch 12/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0207 - mean_absolute_error: 0.1117 - root_mean_squared_error: 0.1439 - val_loss: 0.0283 - val_mean_absolute_error: 0.1232 - val_root_mean_squared_error: 0.1683
# Epoch 13/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0210 - mean_absolute_error: 0.1121 - root_mean_squared_error: 0.1449 - val_loss: 0.0277 - val_mean_absolute_error: 0.1215 - val_root_mean_squared_error: 0.1665
# Epoch 14/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0199 - mean_absolute_error: 0.1098 - root_mean_squared_error: 0.1410 - val_loss: 0.0270 - val_mean_absolute_error: 0.1195 - val_root_mean_squared_error: 0.1643
# Epoch 15/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0195 - mean_absolute_error: 0.1082 - root_mean_squared_error: 0.1397 - val_loss: 0.0265 - val_mean_absolute_error: 0.1184 - val_root_mean_squared_error: 0.1627
# Epoch 16/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0188 - mean_absolute_error: 0.1061 - root_mean_squared_error: 0.1371 - val_loss: 0.0257 - val_mean_absolute_error: 0.1162 - val_root_mean_squared_error: 0.1602
# Epoch 17/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0189 - mean_absolute_error: 0.1065 - root_mean_squared_error: 0.1374 - val_loss: 0.0249 - val_mean_absolute_error: 0.1152 - val_root_mean_squared_error: 0.1580
# Epoch 18/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0180 - mean_absolute_error: 0.1037 - root_mean_squared_error: 0.1343 - val_loss: 0.0243 - val_mean_absolute_error: 0.1130 - val_root_mean_squared_error: 0.1560
# Epoch 19/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0176 - mean_absolute_error: 0.1035 - root_mean_squared_error: 0.1328 - val_loss: 0.0236 - val_mean_absolute_error: 0.1112 - val_root_mean_squared_error: 0.1538
# Epoch 20/160
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0167 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1292 - val_loss: 0.0231 - val_mean_absolute_error: 0.1105 - val_root_mean_squared_error: 0.1520
# Epoch 21/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0168 - mean_absolute_error: 0.1009 - root_mean_squared_error: 0.1298 - val_loss: 0.0226 - val_mean_absolute_error: 0.1087 - val_root_mean_squared_error: 0.1502
# Epoch 22/160
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0162 - mean_absolute_error: 0.0993 - root_mean_squared_error: 0.1273 - val_loss: 0.0220 - val_mean_absolute_error: 0.1078 - val_root_mean_squared_error: 0.1484
# Epoch 23/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0163 - mean_absolute_error: 0.1001 - root_mean_squared_error: 0.1278 - val_loss: 0.0214 - val_mean_absolute_error: 0.1058 - val_root_mean_squared_error: 0.1463
# Epoch 24/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0162 - mean_absolute_error: 0.0981 - root_mean_squared_error: 0.1272 - val_loss: 0.0213 - val_mean_absolute_error: 0.1076 - val_root_mean_squared_error: 0.1459
# Epoch 25/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0158 - mean_absolute_error: 0.0987 - root_mean_squared_error: 0.1257 - val_loss: 0.0206 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1435
# Epoch 26/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0148 - mean_absolute_error: 0.0947 - root_mean_squared_error: 0.1217 - val_loss: 0.0203 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1424
# Epoch 27/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0148 - mean_absolute_error: 0.0944 - root_mean_squared_error: 0.1216 - val_loss: 0.0199 - val_mean_absolute_error: 0.1015 - val_root_mean_squared_error: 0.1412
# Epoch 28/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0137 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1171 - val_loss: 0.0191 - val_mean_absolute_error: 0.0988 - val_root_mean_squared_error: 0.1384
# Epoch 29/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0142 - mean_absolute_error: 0.0936 - root_mean_squared_error: 0.1190 - val_loss: 0.0195 - val_mean_absolute_error: 0.1016 - val_root_mean_squared_error: 0.1395
# Epoch 30/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0140 - mean_absolute_error: 0.0917 - root_mean_squared_error: 0.1184 - val_loss: 0.0191 - val_mean_absolute_error: 0.0998 - val_root_mean_squared_error: 0.1380
# Epoch 31/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0136 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1167 - val_loss: 0.0189 - val_mean_absolute_error: 0.0998 - val_root_mean_squared_error: 0.1376
# Epoch 32/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0130 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1138 - val_loss: 0.0188 - val_mean_absolute_error: 0.0999 - val_root_mean_squared_error: 0.1370
# Epoch 33/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0131 - mean_absolute_error: 0.0888 - root_mean_squared_error: 0.1144 - val_loss: 0.0187 - val_mean_absolute_error: 0.0980 - val_root_mean_squared_error: 0.1367
# Epoch 34/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0130 - mean_absolute_error: 0.0888 - root_mean_squared_error: 0.1142 - val_loss: 0.0183 - val_mean_absolute_error: 0.0967 - val_root_mean_squared_error: 0.1353
# Epoch 35/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0131 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1142 - val_loss: 0.0178 - val_mean_absolute_error: 0.0961 - val_root_mean_squared_error: 0.1335
# Epoch 36/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0129 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1137 - val_loss: 0.0176 - val_mean_absolute_error: 0.0939 - val_root_mean_squared_error: 0.1328
# Epoch 37/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0127 - mean_absolute_error: 0.0865 - root_mean_squared_error: 0.1126 - val_loss: 0.0179 - val_mean_absolute_error: 0.0960 - val_root_mean_squared_error: 0.1340
# Epoch 38/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0123 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1108 - val_loss: 0.0176 - val_mean_absolute_error: 0.0938 - val_root_mean_squared_error: 0.1327
# Epoch 39/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0130 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1142 - val_loss: 0.0178 - val_mean_absolute_error: 0.0955 - val_root_mean_squared_error: 0.1333
# Epoch 40/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0128 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1129 - val_loss: 0.0177 - val_mean_absolute_error: 0.0953 - val_root_mean_squared_error: 0.1329
# Epoch 41/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0125 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1119 - val_loss: 0.0175 - val_mean_absolute_error: 0.0938 - val_root_mean_squared_error: 0.1323
# Epoch 42/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0133 - mean_absolute_error: 0.0887 - root_mean_squared_error: 0.1154 - val_loss: 0.0181 - val_mean_absolute_error: 0.0969 - val_root_mean_squared_error: 0.1345
# Epoch 43/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0124 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1113 - val_loss: 0.0181 - val_mean_absolute_error: 0.0968 - val_root_mean_squared_error: 0.1344
# Epoch 44/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0118 - mean_absolute_error: 0.0847 - root_mean_squared_error: 0.1088 - val_loss: 0.0175 - val_mean_absolute_error: 0.0939 - val_root_mean_squared_error: 0.1323
# Epoch 45/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0123 - mean_absolute_error: 0.0852 - root_mean_squared_error: 0.1109 - val_loss: 0.0174 - val_mean_absolute_error: 0.0937 - val_root_mean_squared_error: 0.1318
# Epoch 46/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0122 - mean_absolute_error: 0.0837 - root_mean_squared_error: 0.1103 - val_loss: 0.0175 - val_mean_absolute_error: 0.0938 - val_root_mean_squared_error: 0.1322
# Epoch 47/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0114 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1069 - val_loss: 0.0169 - val_mean_absolute_error: 0.0921 - val_root_mean_squared_error: 0.1301
# Epoch 48/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0120 - mean_absolute_error: 0.0850 - root_mean_squared_error: 0.1098 - val_loss: 0.0167 - val_mean_absolute_error: 0.0905 - val_root_mean_squared_error: 0.1292
# Epoch 49/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0115 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1073 - val_loss: 0.0166 - val_mean_absolute_error: 0.0898 - val_root_mean_squared_error: 0.1289
# Epoch 50/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1076 - val_loss: 0.0165 - val_mean_absolute_error: 0.0900 - val_root_mean_squared_error: 0.1285
# Epoch 51/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0117 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1080 - val_loss: 0.0165 - val_mean_absolute_error: 0.0893 - val_root_mean_squared_error: 0.1283
# Epoch 52/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0118 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1085 - val_loss: 0.0165 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1285
# Epoch 53/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0110 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1047 - val_loss: 0.0166 - val_mean_absolute_error: 0.0908 - val_root_mean_squared_error: 0.1287
# Epoch 54/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0111 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1055 - val_loss: 0.0166 - val_mean_absolute_error: 0.0900 - val_root_mean_squared_error: 0.1287
# Epoch 55/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0117 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1083 - val_loss: 0.0163 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1279
# Epoch 56/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0113 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1064 - val_loss: 0.0163 - val_mean_absolute_error: 0.0894 - val_root_mean_squared_error: 0.1278
# Epoch 57/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0117 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1082 - val_loss: 0.0161 - val_mean_absolute_error: 0.0896 - val_root_mean_squared_error: 0.1268
# Epoch 58/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0113 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1061 - val_loss: 0.0163 - val_mean_absolute_error: 0.0888 - val_root_mean_squared_error: 0.1276
# Epoch 59/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0111 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1055 - val_loss: 0.0159 - val_mean_absolute_error: 0.0892 - val_root_mean_squared_error: 0.1259
# Epoch 60/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0106 - mean_absolute_error: 0.0788 - root_mean_squared_error: 0.1029 - val_loss: 0.0162 - val_mean_absolute_error: 0.0892 - val_root_mean_squared_error: 0.1271
# Epoch 61/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0109 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1043 - val_loss: 0.0161 - val_mean_absolute_error: 0.0885 - val_root_mean_squared_error: 0.1270
# Epoch 62/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0108 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1041 - val_loss: 0.0159 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1260
# Epoch 63/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0111 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1054 - val_loss: 0.0162 - val_mean_absolute_error: 0.0893 - val_root_mean_squared_error: 0.1273
# Epoch 64/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0103 - mean_absolute_error: 0.0764 - root_mean_squared_error: 0.1013 - val_loss: 0.0159 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1260
# Epoch 65/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0104 - mean_absolute_error: 0.0785 - root_mean_squared_error: 0.1022 - val_loss: 0.0157 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1252
# Epoch 66/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0107 - mean_absolute_error: 0.0791 - root_mean_squared_error: 0.1035 - val_loss: 0.0160 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1264
# Epoch 67/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0105 - mean_absolute_error: 0.0781 - root_mean_squared_error: 0.1025 - val_loss: 0.0157 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1254
# Epoch 68/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0104 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1022 - val_loss: 0.0157 - val_mean_absolute_error: 0.0867 - val_root_mean_squared_error: 0.1252
# Epoch 69/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0104 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1018 - val_loss: 0.0158 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1258
# Epoch 70/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0104 - mean_absolute_error: 0.0779 - root_mean_squared_error: 0.1021 - val_loss: 0.0156 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1249
# Epoch 71/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0105 - mean_absolute_error: 0.0791 - root_mean_squared_error: 0.1025 - val_loss: 0.0154 - val_mean_absolute_error: 0.0862 - val_root_mean_squared_error: 0.1241
# Epoch 72/160
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0104 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1018 - val_loss: 0.0159 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1260
# Epoch 73/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0102 - mean_absolute_error: 0.0766 - root_mean_squared_error: 0.1009 - val_loss: 0.0156 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1251
# Epoch 74/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0105 - mean_absolute_error: 0.0783 - root_mean_squared_error: 0.1024 - val_loss: 0.0155 - val_mean_absolute_error: 0.0854 - val_root_mean_squared_error: 0.1245
# Epoch 75/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0102 - mean_absolute_error: 0.0767 - root_mean_squared_error: 0.1008 - val_loss: 0.0155 - val_mean_absolute_error: 0.0861 - val_root_mean_squared_error: 0.1245
# Epoch 76/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0107 - mean_absolute_error: 0.0784 - root_mean_squared_error: 0.1032 - val_loss: 0.0156 - val_mean_absolute_error: 0.0864 - val_root_mean_squared_error: 0.1250
# Epoch 77/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0103 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1017 - val_loss: 0.0151 - val_mean_absolute_error: 0.0864 - val_root_mean_squared_error: 0.1230
# Epoch 78/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0101 - mean_absolute_error: 0.0761 - root_mean_squared_error: 0.1006 - val_loss: 0.0153 - val_mean_absolute_error: 0.0854 - val_root_mean_squared_error: 0.1238
# Epoch 79/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0100 - mean_absolute_error: 0.0767 - root_mean_squared_error: 0.0998 - val_loss: 0.0153 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1237
# Epoch 80/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0105 - mean_absolute_error: 0.0775 - root_mean_squared_error: 0.1023 - val_loss: 0.0151 - val_mean_absolute_error: 0.0864 - val_root_mean_squared_error: 0.1229
# Epoch 81/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0096 - mean_absolute_error: 0.0741 - root_mean_squared_error: 0.0982 - val_loss: 0.0153 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1236
# Epoch 82/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0099 - mean_absolute_error: 0.0759 - root_mean_squared_error: 0.0996 - val_loss: 0.0151 - val_mean_absolute_error: 0.0860 - val_root_mean_squared_error: 0.1229
# Epoch 83/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0097 - mean_absolute_error: 0.0742 - root_mean_squared_error: 0.0987 - val_loss: 0.0153 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1236
# Epoch 84/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0097 - mean_absolute_error: 0.0756 - root_mean_squared_error: 0.0986 - val_loss: 0.0151 - val_mean_absolute_error: 0.0862 - val_root_mean_squared_error: 0.1229
# Epoch 85/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0099 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.0996 - val_loss: 0.0150 - val_mean_absolute_error: 0.0850 - val_root_mean_squared_error: 0.1225
# Epoch 86/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0096 - mean_absolute_error: 0.0752 - root_mean_squared_error: 0.0981 - val_loss: 0.0150 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1226
# Epoch 87/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0098 - mean_absolute_error: 0.0754 - root_mean_squared_error: 0.0989 - val_loss: 0.0148 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1216
# Epoch 88/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0097 - mean_absolute_error: 0.0749 - root_mean_squared_error: 0.0987 - val_loss: 0.0153 - val_mean_absolute_error: 0.0851 - val_root_mean_squared_error: 0.1237
# Epoch 89/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0093 - mean_absolute_error: 0.0734 - root_mean_squared_error: 0.0966 - val_loss: 0.0148 - val_mean_absolute_error: 0.0843 - val_root_mean_squared_error: 0.1217
# Epoch 90/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0096 - mean_absolute_error: 0.0743 - root_mean_squared_error: 0.0980 - val_loss: 0.0156 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1247
# Epoch 91/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0102 - mean_absolute_error: 0.0763 - root_mean_squared_error: 0.1008 - val_loss: 0.0154 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1239
# Epoch 92/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0094 - mean_absolute_error: 0.0741 - root_mean_squared_error: 0.0971 - val_loss: 0.0150 - val_mean_absolute_error: 0.0866 - val_root_mean_squared_error: 0.1225
# Epoch 93/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0095 - mean_absolute_error: 0.0744 - root_mean_squared_error: 0.0973 - val_loss: 0.0149 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1220
# Epoch 94/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0096 - mean_absolute_error: 0.0743 - root_mean_squared_error: 0.0980 - val_loss: 0.0150 - val_mean_absolute_error: 0.0838 - val_root_mean_squared_error: 0.1226
# Epoch 95/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0100 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1000 - val_loss: 0.0156 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1250
# Epoch 96/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0099 - mean_absolute_error: 0.0761 - root_mean_squared_error: 0.0997 - val_loss: 0.0152 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1235
# Epoch 97/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0094 - mean_absolute_error: 0.0744 - root_mean_squared_error: 0.0967 - val_loss: 0.0149 - val_mean_absolute_error: 0.0853 - val_root_mean_squared_error: 0.1220
# Epoch 98/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0100 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1001 - val_loss: 0.0152 - val_mean_absolute_error: 0.0869 - val_root_mean_squared_error: 0.1231
# Epoch 99/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0094 - mean_absolute_error: 0.0742 - root_mean_squared_error: 0.0971 - val_loss: 0.0152 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1233
# Epoch 100/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0096 - mean_absolute_error: 0.0740 - root_mean_squared_error: 0.0978 - val_loss: 0.0148 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1217
# Epoch 101/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0090 - mean_absolute_error: 0.0721 - root_mean_squared_error: 0.0951 - val_loss: 0.0147 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1211
# Epoch 102/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0094 - mean_absolute_error: 0.0743 - root_mean_squared_error: 0.0970 - val_loss: 0.0149 - val_mean_absolute_error: 0.0854 - val_root_mean_squared_error: 0.1219
# Epoch 103/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0091 - mean_absolute_error: 0.0733 - root_mean_squared_error: 0.0954 - val_loss: 0.0152 - val_mean_absolute_error: 0.0850 - val_root_mean_squared_error: 0.1231
# Epoch 104/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0092 - mean_absolute_error: 0.0731 - root_mean_squared_error: 0.0958 - val_loss: 0.0147 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1214
# Epoch 105/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0091 - mean_absolute_error: 0.0722 - root_mean_squared_error: 0.0952 - val_loss: 0.0147 - val_mean_absolute_error: 0.0849 - val_root_mean_squared_error: 0.1213
# Epoch 106/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0090 - mean_absolute_error: 0.0724 - root_mean_squared_error: 0.0948 - val_loss: 0.0147 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1214
# Epoch 107/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0090 - mean_absolute_error: 0.0725 - root_mean_squared_error: 0.0948 - val_loss: 0.0148 - val_mean_absolute_error: 0.0855 - val_root_mean_squared_error: 0.1216
# Epoch 108/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0090 - mean_absolute_error: 0.0726 - root_mean_squared_error: 0.0947 - val_loss: 0.0146 - val_mean_absolute_error: 0.0854 - val_root_mean_squared_error: 0.1210
# Epoch 109/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0094 - mean_absolute_error: 0.0731 - root_mean_squared_error: 0.0969 - val_loss: 0.0149 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1219
# Epoch 110/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0722 - root_mean_squared_error: 0.0939 - val_loss: 0.0146 - val_mean_absolute_error: 0.0837 - val_root_mean_squared_error: 0.1208
# Epoch 111/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0089 - mean_absolute_error: 0.0728 - root_mean_squared_error: 0.0942 - val_loss: 0.0146 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1208
# Epoch 112/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0092 - mean_absolute_error: 0.0729 - root_mean_squared_error: 0.0961 - val_loss: 0.0148 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1215
# Epoch 113/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0090 - mean_absolute_error: 0.0724 - root_mean_squared_error: 0.0947 - val_loss: 0.0147 - val_mean_absolute_error: 0.0837 - val_root_mean_squared_error: 0.1212
# Epoch 114/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0701 - root_mean_squared_error: 0.0934 - val_loss: 0.0148 - val_mean_absolute_error: 0.0843 - val_root_mean_squared_error: 0.1215
# Epoch 115/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0087 - mean_absolute_error: 0.0710 - root_mean_squared_error: 0.0932 - val_loss: 0.0146 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1207
# Epoch 116/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0718 - root_mean_squared_error: 0.0945 - val_loss: 0.0147 - val_mean_absolute_error: 0.0844 - val_root_mean_squared_error: 0.1212
# Epoch 117/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0724 - root_mean_squared_error: 0.0940 - val_loss: 0.0149 - val_mean_absolute_error: 0.0860 - val_root_mean_squared_error: 0.1222
# Epoch 118/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0711 - root_mean_squared_error: 0.0932 - val_loss: 0.0146 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1208
# Epoch 119/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0713 - root_mean_squared_error: 0.0936 - val_loss: 0.0147 - val_mean_absolute_error: 0.0841 - val_root_mean_squared_error: 0.1210
# Epoch 120/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0709 - root_mean_squared_error: 0.0931 - val_loss: 0.0150 - val_mean_absolute_error: 0.0870 - val_root_mean_squared_error: 0.1225
# Epoch 121/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0703 - root_mean_squared_error: 0.0921 - val_loss: 0.0144 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1200
# Epoch 122/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0714 - root_mean_squared_error: 0.0935 - val_loss: 0.0144 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1198
# Epoch 123/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0713 - root_mean_squared_error: 0.0927 - val_loss: 0.0146 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1208
# Epoch 124/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0080 - mean_absolute_error: 0.0681 - root_mean_squared_error: 0.0895 - val_loss: 0.0144 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1200
# Epoch 125/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0084 - mean_absolute_error: 0.0704 - root_mean_squared_error: 0.0914 - val_loss: 0.0145 - val_mean_absolute_error: 0.0857 - val_root_mean_squared_error: 0.1204
# Epoch 126/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0081 - mean_absolute_error: 0.0685 - root_mean_squared_error: 0.0902 - val_loss: 0.0144 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1201
# Epoch 127/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0079 - mean_absolute_error: 0.0682 - root_mean_squared_error: 0.0891 - val_loss: 0.0142 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1193
# Epoch 128/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0081 - mean_absolute_error: 0.0692 - root_mean_squared_error: 0.0901 - val_loss: 0.0141 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1187
# Epoch 129/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0084 - mean_absolute_error: 0.0702 - root_mean_squared_error: 0.0916 - val_loss: 0.0142 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1192
# Epoch 130/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0081 - mean_absolute_error: 0.0695 - root_mean_squared_error: 0.0902 - val_loss: 0.0142 - val_mean_absolute_error: 0.0840 - val_root_mean_squared_error: 0.1190
# Epoch 131/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0083 - mean_absolute_error: 0.0694 - root_mean_squared_error: 0.0911 - val_loss: 0.0143 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1196
# Epoch 132/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0079 - mean_absolute_error: 0.0683 - root_mean_squared_error: 0.0888 - val_loss: 0.0141 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1189
# Epoch 133/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0085 - mean_absolute_error: 0.0709 - root_mean_squared_error: 0.0921 - val_loss: 0.0143 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1196
# Epoch 134/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0083 - mean_absolute_error: 0.0706 - root_mean_squared_error: 0.0913 - val_loss: 0.0146 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1210
# Epoch 135/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0084 - mean_absolute_error: 0.0710 - root_mean_squared_error: 0.0914 - val_loss: 0.0143 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1195
# Epoch 136/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0078 - mean_absolute_error: 0.0688 - root_mean_squared_error: 0.0884 - val_loss: 0.0139 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1180
# Epoch 137/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0082 - mean_absolute_error: 0.0690 - root_mean_squared_error: 0.0904 - val_loss: 0.0141 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1189
# Epoch 138/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0077 - mean_absolute_error: 0.0677 - root_mean_squared_error: 0.0879 - val_loss: 0.0145 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1204
# Epoch 139/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0084 - mean_absolute_error: 0.0695 - root_mean_squared_error: 0.0914 - val_loss: 0.0142 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1192
# Epoch 140/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0080 - mean_absolute_error: 0.0689 - root_mean_squared_error: 0.0896 - val_loss: 0.0138 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1176
# Epoch 141/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0078 - mean_absolute_error: 0.0672 - root_mean_squared_error: 0.0881 - val_loss: 0.0141 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1189
# Epoch 142/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0081 - mean_absolute_error: 0.0692 - root_mean_squared_error: 0.0901 - val_loss: 0.0143 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1196
# Epoch 143/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0078 - mean_absolute_error: 0.0668 - root_mean_squared_error: 0.0882 - val_loss: 0.0140 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1183
# Epoch 144/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0077 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.0880 - val_loss: 0.0137 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1170
# Epoch 145/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0082 - mean_absolute_error: 0.0692 - root_mean_squared_error: 0.0906 - val_loss: 0.0141 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1189
# Epoch 146/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0077 - mean_absolute_error: 0.0675 - root_mean_squared_error: 0.0875 - val_loss: 0.0141 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1188
# Epoch 147/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0077 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.0878 - val_loss: 0.0138 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1175
# Epoch 148/160
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0078 - mean_absolute_error: 0.0679 - root_mean_squared_error: 0.0886 - val_loss: 0.0140 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1184
# Epoch 149/160
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0077 - mean_absolute_error: 0.0670 - root_mean_squared_error: 0.0878 - val_loss: 0.0139 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1178
# Epoch 150/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0073 - mean_absolute_error: 0.0652 - root_mean_squared_error: 0.0857 - val_loss: 0.0138 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1173
# Epoch 151/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0074 - mean_absolute_error: 0.0659 - root_mean_squared_error: 0.0863 - val_loss: 0.0137 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1169
# Epoch 152/160
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0075 - mean_absolute_error: 0.0658 - root_mean_squared_error: 0.0865 - val_loss: 0.0138 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1173
# Epoch 153/160
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0074 - mean_absolute_error: 0.0658 - root_mean_squared_error: 0.0862 - val_loss: 0.0138 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1176
# Epoch 154/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0076 - mean_absolute_error: 0.0669 - root_mean_squared_error: 0.0869 - val_loss: 0.0139 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1179
# Epoch 155/160
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0076 - mean_absolute_error: 0.0664 - root_mean_squared_error: 0.0872 - val_loss: 0.0136 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1165
# Epoch 156/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0076 - mean_absolute_error: 0.0671 - root_mean_squared_error: 0.0869 - val_loss: 0.0138 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1176
# Epoch 157/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0075 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0864 - val_loss: 0.0136 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1167
# Epoch 158/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0072 - mean_absolute_error: 0.0644 - root_mean_squared_error: 0.0847 - val_loss: 0.0136 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1166
# Epoch 159/160
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0073 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0855 - val_loss: 0.0137 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1170
# Epoch 160/160
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0071 - mean_absolute_error: 0.0646 - root_mean_squared_error: 0.0841 - val_loss: 0.0136 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1168

# %%
# Learning Curve


pd.DataFrame(history.history)[['loss','val_loss']].plot(figsize=(10,7))

plt.ylabel("Cost function",fontsize=15)
plt.xlabel("Epoch",fontsize=15)
plt.savefig('LSTM_TMP_LOSS.png')
files.download("LSTM_TMP_LOSS.png")
plt.show()
pd.DataFrame(history.history)[['mean_absolute_error','val_mean_absolute_error']].plot(figsize=(10,7))
plt.ylabel("Error",fontsize=15)
plt.xlabel("Epoch",fontsize=15)
plt.savefig('LSTM_TMP_ERROR.png')
files.download("LSTM_TMP_ERROR.png")
plt.show()

# %%
# Evaluation pof MSE with the test_generator
model.evaluate(test_generator,verbose=0)

# Predictions
predictions=model.predict(test_generator)

# Consider the values of X_test by ignoring the first 14th
New_X_test=X_test[:,1:][window_length:]

# Datapredicted
df_pred=pd.concat([pd.DataFrame(predictions),pd.DataFrame(New_X_test)],axis=1)
# return the inverse transform of the MinMaxscaler created above to give the real value that we had initially
rev_trans=scaler.inverse_transform(df_pred.values)

# Extraction of the LSTM  prediction and the real value of T2M
df_final=df_input[-predictions.shape[0]:]
df1=df_final['T2M']
rev2=rev_trans[:,0]

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,mean_absolute_percentage_error

# Performance metrics

mse = mean_squared_error(df1, rev2)
r2 = r2_score(df1, rev2)
mae = mean_absolute_error(df1, rev2)
# mae_scaled = mean_absolute_error(X_test[-rev2.shape[0]:,0], predictions[:,0])
mape = mean_absolute_percentage_error(df1, rev2)
print("mse=",mse,3)
print("r2=",r2,3)
print("mae=",mae)
# print("mae_scaled=" + str(round(mae_scaled,2)))
print("mape=",mape)
# Out:
# mse= 0.3185790343463813 3
# r2= 0.6260260185292592 3
# mae= 0.4310269397153073
# mape= 0.016482911735765295

# %%
predictions1.shape
# Out:
# (43, 1)

# %%
from google.colab import files

########## Visualization of LSTM Prediction result ##########

dates = pd.date_range('08/21/2020', periods=498)
dates1 = pd.date_range('01/01/2015', periods=2060)
Forecast=pd.DataFrame({  'LSTM Prediction for T2M ':rev2})
Forecast['date']=dates
For=Forecast.set_index('date')
T=df_input['T2M']
D=T[0:2060].to_frame(' Historical values of the Temperature')
D['Date']=dates1
DD=D.set_index('Date')

mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 15
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 20


sns.set_style("darkgrid")
train_forecast = pd.concat([DD,For])
train_forecast[1000:2600].plot.line(figsize=(20, 5), color=['peru','forestgreen'])

plt.ylabel("T2M",fontsize=20)
plt.xlabel("Date",fontsize=20)

plt.title("LSTM for temperature prediction")
plt.legend(fontsize=15)
plt.savefig('LSTM_TMP_PRED.png')
files.download("LSTM_TMP_PRED.png")
plt.show()

# %%
import matplotlib.dates as mdates
Forecast=pd.DataFrame({'actual values of T2M':df1,'LSTM Prediction ':rev2})
Forecast['date']=dates
For=Forecast.set_index('date')
# For.plot.line(figsize=(17, 4))
train_forecast = pd.concat([DD,For])
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 15
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 20

# train_forecast[2000:2600].plot.line(figsize=(15, 7))
sns.set_style("darkgrid")

For.plot.line(figsize=(15, 4),color=['peru','forestgreen'])
plt.ylabel("T2M",fontsize=18)
plt.xlabel("Date",fontsize=18)
# dates.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# dates.xaxis.set_major_locator(mdates.DayLocator(interval=100))
# dates.tick_params(axis='x', labelrotation=45)
# train_forecast.plot.line(figsize=(35, 7))
plt.title("LSTM for Temperature prediction")
plt.legend(fontsize=15)
plt.savefig('LSTM_TMP_PRED_VS.png')
files.download("LSTM_TMP_PREDx.png")
plt.show()

# %%
# plt.scatter(rev2p, df1p,s=10,linewidths=True)
# plt.ylabel(" True Precipitation values")
# plt.xlabel("Predicted Precipitation values")
# plt.title("Scatter plot")
# Concatenated predicted and real values
